# %%
#importing the required libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.set(style = "whitegrid")

# %%
#reading and storing the dataset in a dataframe named df

df = pd.read_csv("cars.csv")

# %%
df.dtypes
# Out:
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# Make                   object
# dtype: object

# %%
#changing the column names 

df = df.rename(columns = {'MPG.city':'MPGcity' , 'MPG.highway':'MPGhighway'})

# %%
#displaying 5 records

df.sample(5)
# Out:
#      Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPGcity  \
# 28          Dodge  Stealth   Sporty       18.5   25.8       33.1       18
# 31           Ford  Festiva    Small        6.9    7.4        7.9       31
# 11       Cadillac  Seville  Midsize       37.5   40.1       42.7       16
# 58  Mercedes-Benz     190E  Compact       29.0   31.9       34.9       20
# 80         Subaru    Justy    Small        7.3    8.4        9.5       33
#
#     MPGhighway             AirBags DriveTrain  ... Passengers  Length  \
# 28          24         Driver only        4WD  ...          4     180
# 31          33                None      Front  ...          4     141
# 11          25  Driver & Passenger      Front  ...          5     204
# 58          29         Driver only       Rear  ...          5     175
# 80          37                None        4WD  ...          4     146
#
#     Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
#displaying the categories of Man.trans.avail

pd.value_counts(df['Man.trans.avail'])
# Out:
# Yes    61
# No     32
# Name: Man.trans.avail, dtype: int64

# %%
#displaying the numerical summary of the column

df.describe()
# Out:
#        Min.Price      Price  Max.Price    MPGcity  MPGhighway  EngineSize  \
# count  93.000000  93.000000  93.000000  93.000000   93.000000   93.000000
# mean   17.125806  19.509677  21.898925  22.365591   29.086022    2.667742
# std     8.746029   9.659430  11.030457   5.619812    5.331726    1.037363
# min     6.700000   7.400000   7.900000  15.000000   20.000000    1.000000
# 25%    10.800000  12.200000  14.700000  18.000000   26.000000    1.800000
# 50%    14.700000  17.700000  19.600000  21.000000   28.000000    2.400000
# 75%    20.300000  23.300000  25.300000  25.000000   31.000000    3.300000
# max    45.400000  61.900000  80.000000  46.000000   50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   93.000000    93.000000     93.000000           93.000000   93.000000
# mean   143.827957  5280.645161   2332.204301           16.664516    5.086022
# ...

# %% [markdown]
# # PLOTS

# %% [markdown]
# # Boxplots

# %%
#comapring a numerical variable by categories

#comparing city mileage by car's transmission

# %%
#using matlplotlib to adjust the figure size

plt.figure(figsize = (12,6))
sns.boxplot( x = 'Man.trans.avail' , y = 'MPGcity' , data = df)

# %%
plt.figure(figsize = (12,6))
sns.boxplot( x = 'AirBags' , y = 'MPGcity' , data = df)

# %% [markdown]
# # Stripplots

# %%
#plotting with jitter

plt.figure(figsize = (12,6))
sns.stripplot(y = "MPGcity", x = "AirBags", data = df)

# %%
#plotting without jitter

plt.figure(figsize = (12,6))
sns.stripplot(y = "MPGcity", x = "AirBags", data = df , jitter = False)

# %% [markdown]
# # Histograms

# %%
#pandas histogram

df['Price'].plot.hist();

# %%
#plotting density curve

df['Price'].plot.density();

# %%
#we see the range is different in the above two so we set the range 

df['Price'].plot.hist(range = [-20,60]);

# %%
#plotting a seaborn histogram

sns.distplot(df['Price'])

# %% [markdown]
# # Scatterplots

# %%
#using matplotlib

plt.figure(figsize = (12,6))
plt.scatter(df.Horsepower , df.MPGcity , color = 'r' , s = 9)
plt.ylabel('MPGcity')
plt.xlabel('Horsepower');

# %%
#scatter plot using seaborn

plt.figure(figsize = (12,6))
sns.regplot("Horsepower","MPGcity", data = df)

# %%
#lowess smoother

sns.regplot("Horsepower", "MPGcity", data = df , lowess = True)

# %% [markdown]
# # Seaborn lmplot

# %%
#scatterplot and regression lines for cars with different transmission

# %%
sns.lmplot('Horsepower' , 'MPGcity' , data = df
           , hue = 'Man.trans.avail' , height = 7 , aspect = 1.5);

# %%
#removing the confidence bounds

sns.lmplot('Horsepower' , 'MPGcity' , data = df
           , hue = 'Man.trans.avail' , height = 7 , aspect = 1.5 , ci = None);

# %%
#using two facets using two categorical variables 

sns.lmplot('Horsepower' , 'MPGcity' , data = df
           , col = 'Man.trans.avail' , ci = None);

# %%
#using four facets using four categorical variables 

sns.lmplot('Horsepower' , 'MPGcity' , data = df
           , col = 'Man.trans.avail' , row = 'Origin' , ci = None);

# %%
#ploynomial regression with lmplot

sns.lmplot('Horsepower' , 'MPGcity' , data = df , height = 7
           , aspect = 1.5, ci = None);

# %%
#ploynomial regression of order 2 with lmplot

sns.lmplot('Horsepower' , 'MPGcity' , data = df , height = 7
           , aspect = 1.5, ci = None , order = 2);

# %% [markdown]
# # Relplot

# %%
#two scatterplots splitting dataset by Man.trans.avail

# %%
sns.relplot(x = 'Horsepower' ,y = 'MPGcity' , data = df
           , col = 'Man.trans.avail' );

# %%
#manual transmission reaches higher city mileage

# %%
sns.relplot(x = 'Horsepower' ,y = 'MPGcity' , data = df
           , col = 'Man.trans.avail' , hue = 'Origin');

# %%
sns.relplot(x = 'Horsepower' ,y = 'MPGcity' , data = df
           , col = 'Man.trans.avail' , hue = 'AirBags' );

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x = 'EngineSize' ,y = 'MPGcity' , data = df)

# %%
sns.jointplot(x = 'EngineSize' ,y = 'MPGcity' , data = df 
              , kind = 'reg')

# %%
sns.jointplot(x = 'EngineSize' ,y = 'MPGcity' , data = df
              , kind = 'reg' , ci = None)

# %%
#contour plot and density curves

sns.jointplot(x = 'EngineSize' ,y = 'MPGcity' , data = df
             , kind = 'kde');

# %% [markdown]
# # Pairplots

# %%
df2  = df[['Price', 'MPGcity', 'Cylinders' , 'DriveTrain'
          , 'EngineSize' , 'Horsepower' , 'Man.trans.avail']]

# %%
df2[:5]
# Out:
#    Price  MPGcity Cylinders DriveTrain  EngineSize  Horsepower Man.trans.avail
# 1   15.9       25         4      Front         1.8         140             Yes
# 2   33.9       18         6      Front         3.2         200             Yes
# 3   29.1       20         6      Front         2.8         172             Yes
# 4   37.7       19         6      Front         2.8         172             Yes
# 5   30.0       22         4       Rear         3.5         208             Yes

# %%
sns.pairplot(df2, hue = 'Man.trans.avail');
